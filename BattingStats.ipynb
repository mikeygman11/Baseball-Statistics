# %%
'''general idea

take in individual player data (hits, runs, homeruns, etc)
and make an algorithm that will print the league leader in a given category)

Update: 1/15--
- going to start with top batting statistics from the 2019 season
'''

#data preprocessing

from collections import defaultdict
d = defaultdict(list)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import xlrd

# %%
stats = ("2019mlb.xlsx")
wb = xlrd.open_workbook(stats)
sheet = wb.sheet_by_index(0)
sheet.cell_value(0,0)
#first num is column, second num is row

a = [1,2,3,4]
for item in a:
    newVar = a[item-1]
print(newVar)
# Out:
# 4

# %%
row = sheet.row(0)
#print(row)
row2 = sheet.row(1)
#print(row2)
lastNames = sheet.col(0)
firstNames = sheet.col(1)
l = [] #list of last names
f = [] #list of first names
names = [] # formmatted conjoined list


numRows = sheet.nrows
numColumns = sheet.ncols



for i in range(0, 157):
    l.insert(i, str(lastNames[i]))

    
for i in range(0, 157):
     f.insert(i, str(firstNames[i]))


#for i in range (0, 157):
  #  print(p[i][6:-1] + " " + d[i][6:-1])

for i in range (1, 157):
    names.insert(i, f[i][7:-1] + " " + l[i][6:-1])

'''for i in range(0, len(names)):
    k = i + 1
    for j in range (0, len(names)):
        if names[i] == names[j]:
            names[i] + "1"
       ''' 
#print(names)
#gets a list of MLB player's names

d = {}


for i in range(0, len(names)):
    d[names[i]] = {}

    
#generates a dictionary with names as keys and an empty dictionary for value

# %%
years = sheet.col(2)
y = []

    
for i in range(0, 157):
     y.insert(i, str(years[i]))

formattedYears = []

for i in range(0, 157):
     formattedYears.insert(i, y[i][7:-2])

    
for j in range(0, len(names)):
    d[names[j]] = {"Year": formattedYears[j], "Age" : '', "At-Bats" : '', "Plate Appearances" : '', "Hits" : '', "Singles" : '',
                  "Doubles" : '',"Triples" : '', "Home Runs" : '', "Strikeouts" : '', "Walks" : '', "Strikeout Percentage" : '', "Walk Percentage" : '',
                  "Batting Average": '', "Slugging Percentage" : '', "On-Base Percentage" : '', "On-Base Plus Slugging Percentage" : '', 
                   "Runs Batted In" : '', "Total Bases" : '', "Caught Stealing" : '', "Stolen Bases" : '', "Average Exit Velocity" : '', 
                   "Average Launch Angle" : ''}

d["Albert Pujols"]["Year"] = 2019


age = sheet.col(3)
a = []

    
for i in range(0, 157):
     a.insert(i, str(age[i]))

ageFormatted = []

for i in range(1, 157):
     ageFormatted.insert(i, a[i][7:-2])


for j in range(0, len(names)):
    d[names[j]]["Age"] =  ageFormatted[j]

# %%
#now that the general idea has been layed out, I can go ahead and start doing this dictionary implementation for all stats

ab = sheet.col(4)
atBats = []

    
for i in range(0, 157):
     atBats.insert(i, str(ab[i]))

formatAtBats = []

for i in range(1, 157):
     formatAtBats.insert(i, atBats[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["At-Bats"] =  formatAtBats[j]

# %%
pa = sheet.col(5)
plate = []

    
for i in range(0, 157):
     plate.insert(i, str(pa[i]))

formatPA = []

for i in range(1, 157):
     formatPA.insert(i, plate[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Plate Appearances"] =  formatPA[j]

# %%
h = sheet.col(6)
hits = []

    
for i in range(0, 157):
     hits.insert(i, str(h[i]))

hit = []

for i in range(1, 157):
     hit.insert(i, hits[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Hits"] =  hit[j]

# %%
s = sheet.col(7)
si = []

    
for i in range(0, 157):
     si.insert(i, str(s[i]))

single = []

for i in range(1, 157):
     single.insert(i, si[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Singles"] =  single[j]

# %%
dd = sheet.col(8)
dds = []

    
for i in range(0, 157):
     dds.insert(i, str(dd[i]))

double = []

for i in range(1, 157):
     double.insert(i, dds[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Doubles"] =  double[j]

# %%
t = sheet.col(9)
trip = []

    
for i in range(0, 157):
     trip.insert(i, str(t[i]))

triples = []

for i in range(1, 157):
     triples.insert(i, trip[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Triples"] =  triples[j]

# %%
hr = sheet.col(10)
homers = []

    
for i in range(0, 157):
     homers.insert(i, str(hr[i]))

homeruns = []

for i in range(1, 157):
     homeruns.insert(i, homers[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Home Runs"] =  homeruns[j]

# %%
SO = sheet.col(11)
Ks = []

    
for i in range(0, 157):
     Ks.insert(i, str(SO[i]))

strikeouts = []

for i in range(1, 157):
     strikeouts.insert(i, Ks[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Strikeouts"] =  strikeouts[j]

# %%
w = sheet.col(12)
bb = []

    
for i in range(0, 157):
     bb.insert(i, str(w[i]))

walks = []

for i in range(1, 157):
     walks.insert(i, bb[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Walks"] =  walks[j]

# %%
strike = sheet.col(13)
kperc = []

    
for i in range(0, 157):
     kperc.insert(i, str(strike[i]))

kpercentage = []

for i in range(1, 157):
     kpercentage.insert(i, kperc[i][7:])

for j in range(0, len(names)):
    d[names[j]]["Strikeout Percentage"] =  kpercentage[j]

# %%
walk = sheet.col(14)
walkperc = []

    
for i in range(0, 157):
     walkperc.insert(i, str(walk[i]))

walkpercentage = []

for i in range(1, 157):
     walkpercentage.insert(i, walkperc[i][7:])

for j in range(0, len(names)):
    d[names[j]]["Walk Percentage"] =  walkpercentage[j]

# %%
avg = sheet.col(15)
ba = []

    
for i in range(0, 157):
     ba.insert(i, str(avg[i]))

average = []

for i in range(1, 157):
     average.insert(i, ba[i][7:])

for j in range(0, len(names)):
    d[names[j]]["Batting Average"] =  average[j]

# %%
slg = sheet.col(16)
slugg = []

    
for i in range(0, 157):
     slugg.insert(i, str(slg[i]))

slgperc = []

for i in range(1, 157):
     slgperc.insert(i, slugg[i][7:])

for j in range(0, len(names)):
    d[names[j]]["Slugging Percentage"] =  slgperc[j]

# %%
obp = sheet.col(17)
ob = []

    
for i in range(0, 157):
     ob.insert(i, str(obp[i]))

onBase = []

for i in range(1, 157):
     onBase.insert(i, ob[i][7:])

for j in range(0, len(names)):
    d[names[j]]["On-Base Percentage"] =  onBase[j]

# %%
ops = sheet.col(18)
plus = []

    
for i in range(0, 157):
     plus.insert(i, str(ops[i]))

onBasePlugSlugging = []

for i in range(1, 157):
     onBasePlugSlugging.insert(i, plus[i][7:])

for j in range(0, len(names)):
    d[names[j]]["On-Base Plus Slugging Percentage"] =  onBasePlugSlugging[j]

# %%
rbi = sheet.col(19)
r = []

    
for i in range(0, 157):
     r.insert(i, str(rbi[i]))

runsBattedIn = []

for i in range(1, 157):
     runsBattedIn.insert(i, r[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Runs Batted In"] =  runsBattedIn[j]

# %%
tb = sheet.col(20)
bases = []

    
for i in range(0, 157):
     bases.insert(i, str(tb[i]))

totalBases = []

for i in range(1, 157):
    totalBases.insert(i, bases[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Total Bases"] =  totalBases[j]

# %%
cs = sheet.col(21)
caught = []

    
for i in range(0, 157):
     caught.insert(i, str(cs[i]))

caughtStealing = []

for i in range(1, 157):
     caughtStealing.insert(i, caught[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Caught Stealing"] =  caughtStealing[j]

# %%
sb = sheet.col(22)
stolen = []

    
for i in range(0, 157):
     stolen.insert(i, str(sb[i]))

stolenBases = []

for i in range(1, 157):
     stolenBases.insert(i, stolen[i][7:-2])

for j in range(0, len(names)):
    d[names[j]]["Stolen Bases"] =  stolenBases[j]

# %%
ev = sheet.col(23)
exit = []

    
for i in range(0, 157):
    exit.insert(i, str(ev[i]))

exitVelocity = []

for i in range(1, 157):
     exitVelocity.insert(i, exit[i][7:])

for j in range(0, len(names)):
    d[names[j]]["Average Exit Velocity"] =  exitVelocity[j]

# %%
la = sheet.col(24)
launch = []

    
for i in range(0, 157):
    launch.insert(i, str(la[i]))

launchAngle = []

for i in range(1, 157):
     launchAngle.insert(i, launch[i][7:])

for j in range(0, len(names)):
    d[names[j]]["Average Launch Angle"] =  launchAngle[j]

# %%
print(d["Pete Alonso"]["Home Runs"])

#test case to ensure that all data is corretly displayed to the screen
# Out:
# 53

# %%
#converting all string values to integers
for key in d:
    
    d[key]["Age"] = int(d[key]["Age"])
    d[key]["At-Bats"] = int(d[key]["At-Bats"])
    d[key]["Plate Appearances"] = int(d[key]["Plate Appearances"])
    d[key]["Hits"] = int(d[key]["Hits"])
    d[key]["Singles"] = int(d[key]["Singles"])
    d[key]["Doubles"] = int(d[key]["Doubles"])
    d[key]["Triples"] = int(d[key]["Triples"])
    d[key]["Home Runs"] = int(d[key]["Home Runs"])
    d[key]["Strikeouts"] = int(d[key]["Strikeouts"])
    d[key]["Walks"] = int(d[key]["Walks"])
    d[key]["Strikeout Percentage"] = float(d[key]["Strikeout Percentage"])
    d[key]["Walk Percentage"] = float(d[key]["Walk Percentage"])
    d[key]["Batting Average"] = float(d[key]["Batting Average"])
    d[key]["Slugging Percentage"] = float(d[key]["Slugging Percentage"])
    d[key]["On-Base Percentage"] = float(d[key]["On-Base Percentage"])
    d[key]["On-Base Plus Slugging Percentage"] = float(d[key]["On-Base Plus Slugging Percentage"])
    d[key]["Runs Batted In"] = int(d[key]["Runs Batted In"])
    d[key]["Total Bases"] = int(d[key]["Total Bases"])
    d[key]["Caught Stealing"] = int(d[key]["Caught Stealing"])
    d[key]["Stolen Bases"] = int(d[key]["Stolen Bases"])
    d[key]["Average Exit Velocity"] = float(d[key]["Average Exit Velocity"])
    d[key]["Average Launch Angle"] = float(d[key]["Average Launch Angle"])



    
#algorithm that finds the max in a nested dictionary 
age = 0
ab = 0
pa = 0
hit = 0
singles = 0
doubles = 0
triples = 0
homeruns = 0
so = 0
walks = 0
kperc = 0
wperc = 0
ba = 0
slg = 0
obp = 0
ops = 0
rbi = 0
tb = 0
cs = 0
sb = 0
aev = 0
ala = 0


for k,x in d.items():
    if age < int(x['Age']):
        age = int(x['Age'])
    if ab < int(x['At-Bats']):
        ab = int(x['At-Bats'])
    if pa < int(x['Plate Appearances']):
        pa = int(x['Plate Appearances'])
    if hit < int(x['Hits']):
        hit = int(x['Hits'])
    if singles < int(x['Singles']):
        singles = int(x['Singles'])
    if doubles < int(x['Doubles']):
        doubles = int(x['Doubles'])
    if triples < int(x['Triples']):
        triples = int(x['Triples'])
    if homeruns < int(x['Home Runs']):
        homeruns = int(x['Home Runs'])
    if so < int(x['Strikeouts']):
        so = int(x['Strikeouts'])
    if walks < int(x['Walks']):
        walks = int(x['Walks'])
    if kperc < float(x['Strikeout Percentage']):
        kperc = float(x['Strikeout Percentage'])
    if wperc < float(x['Walk Percentage']):
        wperc = float(x['Walk Percentage'])
    if ba < float(x['Batting Average']):
        ba = float(x['Batting Average'])
    if slg < float(x['Slugging Percentage']):
        slg = float(x['Slugging Percentage'])
    if obp < float(x['On-Base Percentage']):
        obp = float(x['On-Base Percentage'])
    if ops < float(x['On-Base Plus Slugging Percentage']):
        ops = float(x['On-Base Plus Slugging Percentage'])
    if rbi < int(x['Runs Batted In']):
        rbi = int(x['Runs Batted In'])
    if tb < int(x['Total Bases']):
        tb = int(x['Total Bases'])
    if cs < int(x['Caught Stealing']):
        cs = int(x['Caught Stealing'])
    if sb < int(x['Stolen Bases']):
        sb = int(x['Stolen Bases'])
    if aev < float(x['Average Exit Velocity']):
        aev = float(x['Average Exit Velocity'])
    if ala < float(x['Average Launch Angle']):
        ala = float(x['Average Launch Angle'])

        
userIn = input(str("What MLB offensive category would you like to see the league leader of?"))

for key in d:
    if d[key]["Age"] == age:
        if userIn == "Age" or userIn == "age":
            print (key + " is the oldest player in MLB baseball in 2019. He is " + str(age) + " years old.")
    if d[key]["At-Bats"] == ab:
        if userIn == "At-Bats" or userIn == "at-bats" or userIn == 'atbats' or userIn == 'AtBats' or userIn == "At Bats" or userIn == "at bats":
            print (key + " had the most At-Bats in MLB baseball in 2019. He had " + str(ab) + " At-Bats.")
    if d[key]["Plate Appearances"] == pa:
        if userIn == "Plate Appearances" or userIn == "plate appearances":
            print (key + " had the most Plate Appearances in MLB baseball in 2019. He had " + str(age) + " Plate Appearances.")
    if d[key]["Hits"] == hit:
        if userIn == 'hits' or userIn == "Hits":
            print (key + " had the most hits in MLB baseball in 2019. He had " + str(hit) + " hits.")
    if d[key]["Singles"] == singles:
        if userIn == "Singles" or userIn == "singles" or userIn == "1B" or userIn == "1b" or userIn == "1bs" or userIn == "1Bs" or userIn == "1BS":
            print (key + " had the most singles in MLB baseball in 2019. He had " + str(singles) + " singles.")
    if d[key]["Doubles"] == doubles:
        if userIn == "Doubles" or userIn == "doubles" or userIn == "2B" or userIn == "2b" or userIn == "2bs" or userIn == "2Bs" or userIn == "2BS":
            print (key + " had the most doubles in MLB baseball in 2019. He had " + str(doubles) + " doubles.")
    if d[key]["Triples"] == triples:
        if userIn == "Triples" or userIn == "triples" or userIn == "3B" or userIn == "3b" or userIn == "3bs" or userIn == "3Bs" or userIn == "3BS":
            print (key + " hit the most triples in MLB baseball in 2019. He hit " + str(triples) + " triples.")
    if d[key]["Home Runs"] == homeruns:
        if userIn == "Home Runs" or userIn == "home runs" or userIn == "homers" or userIn == "homeruns" or userIn == "Homeruns" or userIn == "HR" or userIn == "hrs" or userIn == "HRs" or userIn == "HRS":
            print (key + " hit the most homeruns in MLB baseball in 2019. He hit " + str(homeruns) + " homeruns.")
    if d[key]["Strikeouts"] == so:
        if userIn == "Strikeouts" or userIn == "strikeouts" or userIn == "K" or userIn == "k" or userIn == "Strike Outs" or userIn == "Strike outs" or userIn == "strike outs" or userIn == "Ks" or userIn == "KS"  or userIn == "ks":
            print (key + " had the most strikeouts in MLB baseball in 2019. He had " + str(so) + " strikeouts.")
    if d[key]["Walks"] == walks:
        if userIn == "Walks" or userIn == "walks" or userIn == "BB" or userIn == "bb" or userIn == "bbs" or userIn == "BBS"  or userIn == "BBs":
            print (key + " had the most walks in MLB baseball in 2019. He had " + str(walks) + " walks.")
    if d[key]["Strikeout Percentage"] == kperc:
        if userIn == "Strikeout Percentage" or userIn == "Stikeout Percentage" or userIn == "K%" or userIn == "k%" or userIn == "Strike Out Percentage" or userIn == "Strike out Percentage" or userIn == "strike out Percentage":
            print (key + " had the highest Strikeout Percentage in MLB baseball in 2019. His Strikeout Percentage was  " + str(kperc) + " %.")
    if d[key]["Walk Percentage"] == wperc:
        if userIn == "Walk Percentage" or userIn == "walk percentage" or userIn == "BB%" or userIn == "bb%":
            print (key + " had the highest Walk Percentage in MLB baseball in 2019. His Walk Percentage was  " + str(wperc) + " %.")
    if d[key]["Batting Average"] == ba:
        if userIn == "Batting Average" or userIn == "batting average" or userIn == "BA" or userIn == "ba" or userIn == "batting" or userIn == "Average" or userIn == "average":
            print (key + " had the highest Batting Average in MLB baseball in 2019. His Batting Average was  " + str(ba) + ".")
    if d[key]["Slugging Percentage"] == slg:
        if userIn == "Slugging Percentage" or userIn == "SLG Percentage" or userIn == "SLG" or userIn == "slugging" or userIn == "Slugging" or userIn == "slugging percentage" or userIn == "SLG%"  or userIn == "slg%"  or userIn == "slg":
            print (key + " had the highest Slugging Percentage in MLB baseball in 2019. His Slugging Percentage was  " + str(slg) + ".")
    if d[key]["On-Base Percentage"] == obp:
        if userIn == "On-Base Percentage" or userIn == "OB Percentage" or userIn == "OBP" or userIn == "obp" or userIn == "On Base Percentage" or userIn == "on base percentage" or userIn == "on-base percentage%"  or userIn == "On base percentage":
            print (key + " had the highest On-Base Percentage in MLB baseball in 2019. His Slugging Percentage was  " + str(obp) + ".")
    if d[key]["On-Base Plus Slugging Percentage"] == ops:
        if userIn == "On-Base Plus Slugging Percentage" or userIn == "On base plus slugging Percentage" or userIn == "on base plus slugging" or userIn == "on-base plus slugging" or userIn == "OPS" or userIn == "OPS%" or userIn == "ops%"  or userIn == "ops":
            print (key + " had the highest On-Base Plus Slugging Percentage in MLB baseball in 2019. His On-Base Plus Slugging Percentage was  " + str(ops) + ".")
    if d[key]["Runs Batted In"] == rbi:
        if userIn == "Runs Batted In" or userIn == "RBI" or userIn == "rbi" or userIn == "runs batted in" or userIn == "Runs batted in" or userIn == "RBIs" or userIn == "RBIS%"  or userIn == "rbis":
            print (key + " had the most Runs Batted In in MLB baseball in 2019. He had  " + str(rbi) + " Runs Batted In.")
    if d[key]["Total Bases"] == tb:
        if userIn == "Total Bases" or userIn == "Total bases" or userIn == "bases" or userIn == "tb" or userIn == "TB" or userIn == "total bases":
            print (key + " had the most Total Bases In in MLB baseball in 2019. He had  " + str(tb) + " Total Bases.")
    if d[key]["Caught Stealing"] == cs:
        if userIn == "Caught Stealing" or userIn == "caught stealing" or userIn == "Caught stealing" or userIn == "CS" or userIn == "cs" or userIn == "caught":
            print (key + " had the most Caught Stealings in MLB baseball in 2019. He was caught stealing  " + str(cs) + "  times.")
    if d[key]["Stolen Bases"] == sb:
        if userIn == "Stolen Bases" or userIn == "stolen bases" or userIn == "SB" or userIn == "sb" or userIn == "SBs" or userIn == "Stolen bases" or userIn == "Bases stolen" or userIn == "bases stolen" or userIn == "Bases Stolen" or userIn == "stolen" or userIn == "Stolen":
            print (key + " had the most Stolen Bases in MLB baseball in 2019. He had " + str(sb) + "  Stolen Bases.")
    if d[key]["Average Exit Velocity"] == aev:
        if userIn == "Average Exit Velocity" or userIn == "Exit Velocity" or userIn == "EV" or userIn == "ev" or userIn == "AEV" or userIn == "aev" or userIn== "Exit velocity" or userIn == "exit velocity" or userIn == "Average exit velocity" or userIn == "average exit velocity" or userIn == "Exit Velo" or userIn == "exit":
            print (key + " had the highest Average Exit Velocity in MLB baseball in 2019. He had an Average Exit Velocity of " + str(aev) + " MPH.")
    if d[key]["Average Launch Angle"] == ala:
        if userIn == "Average Launch Angle" or userIn == "ALA" or userIn == "ala" or userIn == "Average launch angle" or userIn == "Launch Angle" or userIn == "Launch angle" or userIn == "launch angle" or userIn == "average launch angle" or userIn == "launch":
            print (key + " had the highest Average Launch Angle in MLB baseball in 2019. He had an Average Launch Angle of " + str(ala) + " degrees.")
